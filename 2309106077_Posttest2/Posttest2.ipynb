# %% [markdown]
# # Nama : Muhammad Iqbal Fadiatama
# # NIM : 2309106077

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Medicaldataset.csv")

# %% [markdown]
# # 1. Tampilkan rata-rata, standar deviasi, nilai minimum, nilai maksimum, Q1, Q2, dan Q3 dari attribute bertipe angka.

# %%
numeric_stats = df.describe()
display(numeric_stats)
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.191812     0.659591    78.336619               127.170584
# std      13.647315     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %% [markdown]
# # 2. Tampilkan 10 record pertama dari dataset dengan attribute bertipe angka.

# %%
display(df.select_dtypes(include="number").head(10))
# Out:
#    Age  Gender  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0   64       1          66                      160                        83
# 1   21       1          94                       98                        46
# 2   55       1          64                      160                        77
# 3   64       1          70                      120                        55
# 4   55       1          64                      112                        65
# 5   58       0          61                      112                        58
# 6   32       0          40                      179                        68
# 7   63       1          60                      214                        82
# 8   44       0          60                      154                        81
# 9   67       1          61                      160                        95
#
#    Blood sugar   CK-MB  Troponin
# 0        160.0    1.80     0.012
# 1        296.0    6.75     1.060
# ...

# %% [markdown]
# # 3. Tampilkan informasi jumlah record, jumlah attribute, nama attribute, jumlah attribute dengan tipe angka.

# %%
print("Jumlah record:", len(df))
print("Jumlah attribute:", df.shape[1])
print("\nNama attribute:")
display(df.columns.tolist())
print("\nJumlah attribute numerik:", len(df.select_dtypes(include="number").columns))
# Out:
# Jumlah record: 1319
# Jumlah attribute: 9
#
# Nama attribute:
# ['Age',
#  'Gender',
#  'Heart rate',
#  'Systolic blood pressure',
#  'Diastolic blood pressure',
#  'Blood sugar',
#  'CK-MB',
#  'Troponin',
#  'Result']
# Jumlah attribute numerik: 8

# %% [markdown]
# # 4. Tampilkan jumlah label dari semua attribute yang bernilai object

# %%
for col in df.select_dtypes(include=["object"]).columns:
    display(df[col].value_counts())
# Out:
# Result
# positive    810
# negative    509
# Name: count, dtype: int64

# %% [markdown]
# # 5. Visualisai Dataset dengan menggunakan Histogram

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["Age"], bins=30, kde=True)
plt.title("Distribusi Usia Pasien")
plt.xlabel("Umur")
plt.ylabel("Jumlah")
plt.show()

# %% [markdown]
# # 6. Tampilkan korelasi dataset menggunakan heatmap.

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Heatmap Korelasi Antar Variabel Numerik")
plt.show()

# %% [markdown]
# # 7. Kesimpulan Analasis
#
# 1. Mayoritas pasien berada pada rentang usia **40–70 tahun**, dengan rata-rata 56 tahun.
# 2. Tekanan darah sistolik dan diastolik memiliki korelasi positif yang kuat.
# 3. Atribut biomarker (CK-MB, Troponin) menunjukkan adanya **outlier signifikan**, yang bisa jadi indikasi kondisi medis serius.
# 4. Distribusi hasil diagnosis: 810 pasien positif, 509 negatif.
# 5. Dataset ini relevan untuk analisis prediktif kesehatan, misalnya deteksi dini penyakit jantung.
